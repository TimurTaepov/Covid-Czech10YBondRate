# %% [markdown]
# <a href="https://colab.research.google.com/github/TimurTaepov/Covid-Czech10YBondRate/blob/main/(1)%201%20Assignment%20Timur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
A = cv2.imread("watch.pgm", cv2.IMREAD_GRAYSCALE)
cv2_imshow(A)
# Out:
# <PIL.Image.Image image mode=L size=378x504 at 0x7F5CE5A30750>

# %% [markdown]
# ### The formula for the intensity of the (i, j)-th pixel of the target image, that is, express a2i,j in terms of the source image intensities a1k,l is looks like this:
# ![Screenshot 2022-03-02 at 16.19.16.png](data:image/png;base64,...)

# %% [markdown]
# ### Suppose we scale a given image by a scale factor of c = 0.25, using bilinear interpolation

# %%
A1 = cv2.imread("watch.pgm", cv2.IMREAD_GRAYSCALE)
# cv2_imshow(A1)


M1 = A1.shape[0]
N1 = A1.shape[1]


c = 0.25 # Set a scale factor of c = 0.25
M2 = round(c * M1)
N2 = round(c * N1)
A2 = np.zeros((M2,N2))

# Use a bilinear interpolation
for i in range(0,M2):
  for j in range(0,N2):
    x = (i + 0.5) * M1/M2     
    y = (j + 0.5) * N1/N2     
    k = round(x) - 1
    l = round(y) - 1
    k = min( max( k, 0 ), M1-2 )      
    l = min( max( l, 0 ), N1-2 )      
    u = x - k - 0.5
    v = y - l - 0.5
    A2[i,j] = round( (1-v) * ( (1-u)*A1[k,l] + u*A1[k+1,l] ) + v * ( (1-u)*A1[k,l+1] + u*A1[k+1,l+1] ) )

cv2_imshow(A2)
# Out:
# <PIL.Image.Image image mode=L size=94x126 at 0x7F5CE4953E10>

# %% [markdown]
# # Then on slide 14 we can find a zoom out algorithm.![Screenshot 2022-03-02 at 16.23.34.png](data:image/png;base64,...)

# %% [markdown]
# ### Let's use this algorithm for zooming out by a factor of z = 1/c = 4.

# %%
A1 = cv2.imread("watch.pgm", cv2.IMREAD_GRAYSCALE)
# cv2_imshow(A1)


M1 = A1.shape[0]
N1 = A1.shape[1]


z = 5
M2 = np.floor(M1/z).astype(int)
N2 = np.floor(N1/z).astype(int)
A2 = np.zeros((M2,N2))


for i in range(0,M2):
  for j in range(0,N2):
    for k in range(0,z):
      for l in range(0,z):
        A2[i,j] += A1[z*i+k,z*j+l]
A2 /= pow(z,2)

cv2_imshow(A2)
# Out:
# <PIL.Image.Image image mode=L size=75x100 at 0x7F5CE4717D50>

# %% [markdown]
# ## ![bilinear.png](data:image/png;base64,...)In general, bilinear interpolation approach should give us an output with a smoother picture than nearest neighbour interpolation approach. However in our case we can see the opposite situation.
# Lower picture "Nearest neighbour interpolation" | Upper picture "Bilinear interpolation"
# ![Screenshot 2022-03-02 at 16.41.25.png](data:image/png;base64,...)

# %% [markdown]
# It seems to me that the use of bilinear interpolation in order to reduce resolution the picture in this case leads to the predominance of extreme values shades in the quadrants in which the point falls when decreasing. In some places we see almost black zones, in some places completely white. It all depends on the quadrant, however some quadrants that are completely black give us black pixels and in this case the bilinear interpolation weights do not help.
#
# Example of this thing is reflected on the lower picture

# %% [markdown]
# ![Screenshot 2022-03-05 at 12.22.10.png](data:image/png;base64,...)

# %% [markdown]
# In turn, the nearest neighbor helps us much better with the reduction of the amount of pixels in image, averaging the necessary areas and due to this the image is smoother.
#
#  Paradoxically

# %% [markdown]
# ### With c = 0.2 or z = 5 we are having the same situation

# %%
A1 = cv2.imread("watch.pgm", cv2.IMREAD_GRAYSCALE)
# cv2_imshow(A1)


M1 = A1.shape[0]
N1 = A1.shape[1]


c = 0.2 # Set a scale factor of c = 0.25
M2 = round(c * M1)
N2 = round(c * N1)
A2 = np.zeros((M2,N2))

# Use a bilinear interpolation
for i in range(0,M2):
  for j in range(0,N2):
    x = (i + 0.5) * M1/M2     
    y = (j + 0.5) * N1/N2     
    k = round(x) - 1
    l = round(y) - 1
    k = min( max( k, 0 ), M1-2 )      
    l = min( max( l, 0 ), N1-2 )      
    u = x - k - 0.5
    v = y - l - 0.5
    A2[i,j] = round( (1-v) * ( (1-u)*A1[k,l] + u*A1[k+1,l] ) + v * ( (1-u)*A1[k,l+1] + u*A1[k+1,l+1] ) )

cv2_imshow(A2)
# Out:
# <PIL.Image.Image image mode=L size=76x101 at 0x7F5CE4953AD0>

# %%
A1 = cv2.imread("watch.pgm", cv2.IMREAD_GRAYSCALE)
# cv2_imshow(A1)


M1 = A1.shape[0]
N1 = A1.shape[1]


z = 5
M2 = np.floor(M1/z).astype(int)
N2 = np.floor(N1/z).astype(int)
A2 = np.zeros((M2,N2))


for i in range(0,M2):
  for j in range(0,N2):
    for k in range(0,z):
      for l in range(0,z):
        A2[i,j] += A1[z*i+k,z*j+l]
A2 /= pow(z,2)

cv2_imshow(A2)
# Out:
# <PIL.Image.Image image mode=L size=75x100 at 0x7F5CE46FB2D0>
